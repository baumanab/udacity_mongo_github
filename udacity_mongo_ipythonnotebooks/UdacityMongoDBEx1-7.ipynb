# %%
cd ../Udacity/udacity_mongo/
# Out:
# C:\Users\Andrew\Documents\Udacity\udacity_mongo

# %%
# Your task is to read the input DATAFILE line by line, and for the first 10 lines (not including the header)
# split each line on "," and then for each line, create a dictionary
# where the key is the header title of the field, and the value is the value of that field in the row.
# The function parse_file should return a list of dictionaries,
# each data line in the file being a single list entry.
# Field names and values should not contain extra whitespace, like spaces or newline characters.
# You can use the Python string method strip() to remove the extra whitespace.
# You have to parse only the first 10 data lines in this exercise,
# so the returned list should have 10 entries!
import os

DATADIR = ""
DATAFILE = "beatles-diskography.csv"


def parse_file(datafile):
    data = []
    with open(datafile, "rb") as f:
        head = f.readline()
        keys = head.strip().split(",")
        lines = [line for line in f][0:10]
        for line in lines:
                data.append(dict(zip(keys,line.strip().split(","))))
        return len(data),data

def test():
    # a simple test of your implemetation
    datafile = os.path.join(DATADIR, DATAFILE)
    d = parse_file(datafile)
    firstline = {'Title': 'Please Please Me', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '22 March 1963', 'US Chart Position': '-', 'RIAA Certification': 'Platinum', 'BPI Certification': 'Gold'}
    tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}

    assert d[0] == firstline
    assert d[9] == tenthline

    
test()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-2c314d96a9e2> in <module>()
#      35
#      36
# ---> 37 test()
#
# <ipython-input-2-2c314d96a9e2> in test()
#      31     tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}
#      32
# ---> 33     assert d[0] == firstline
#      34     assert d[9] == tenthline
#      35
#
# AssertionError:

# %%
parse_file('beatles-diskography.csv')
# Out:
# (10,
#  [{'BPI Certification': 'Gold',
#    'Label': 'Parlophone(UK)',
#    'RIAA Certification': 'Platinum',
#    'Released': '22 March 1963',
#    'UK Chart Position': '1',
#    'US Chart Position': '\xe2\x80\x94',
#    '\xef\xbb\xbfTitle': 'Please Please Me'},
#   {'BPI Certification': 'Platinum',
#    'Label': 'Parlophone(UK)',
#    'RIAA Certification': 'Gold',
#    'Released': '22 November 1963',
#    'UK Chart Position': '1',
#    'US Chart Position': '\xe2\x80\x94',
#    '\xef\xbb\xbfTitle': 'With the Beatles'},
#   {'BPI Certification': '',
#    'Label': 'Capitol(CAN)',
#    'RIAA Certification': '',
#    'Released': '25 November 1963',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '\xe2\x80\x94',
#    '\xef\xbb\xbfTitle': 'Beatlemania! With the Beatles'},
#   {'BPI Certification': '',
#    'Label': 'Vee-Jay(US)',
#    'RIAA Certification': '',
#    'Released': '10 January 1964',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '2',
#    '\xef\xbb\xbfTitle': 'Introducing... The Beatles'},
#   {'BPI Certification': '',
#    'Label': 'Capitol(US)',
#    'RIAA Certification': '5xPlatinum',
#    'Released': '20 January 1964',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '1',
#    '\xef\xbb\xbfTitle': 'Meet the Beatles!'},
#   {'BPI Certification': '',
#    'Label': 'Capitol(CAN)',
#    'RIAA Certification': '',
#    'Released': '3 February 1964',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '\xe2\x80\x94',
#    '\xef\xbb\xbfTitle': 'Twist and Shout'},
#   {'BPI Certification': '',
#    'Label': 'Capitol(US)',
#    'RIAA Certification': '2xPlatinum',
#    'Released': '10 April 1964',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '1',
#    '\xef\xbb\xbfTitle': "The Beatles' Second Album"},
#   {'BPI Certification': '',
#    'Label': 'Capitol(CAN)',
#    'RIAA Certification': '',
#    'Released': '11 May 1964',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '\xe2\x80\x94',
#    '\xef\xbb\xbfTitle': "The Beatles' Long Tall Sally"},
#   {'BPI Certification': '',
#    'Label': 'United Artists(US)[C]',
#    'RIAA Certification': '4xPlatinum',
#    'Released': '26 June 1964',
#    'UK Chart Position': '\xe2\x80\x94',
#    'US Chart Position': '1',
#    '\xef\xbb\xbfTitle': "A Hard Day's Night"},
#   {'BPI Certification': 'Gold',
#    'Label': 'Parlophone(UK)',
#    'RIAA Certification': '',
#    'Released': '10 July 1964',
#    'UK Chart Position': '1',
#    'US Chart Position': '\xe2\x80\x94',
#    '\xef\xbb\xbfTitle': ''}])

# %%
import csv

def parse_csv(datafile):
    csvdata = []
    n = 0
    with open(datafile, 'rb') as sd:
        r = csv.DictReader(sd)
        for line in r:
            csvdata.append(line)
    return csvdata

# %%
parse_csv('beatles-diskography.csv')
# Out:
# [{'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Platinum',
#   'Released': '22 March 1963',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Please Please Me'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Gold',
#   'Released': '22 November 1963',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'With the Beatles'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '25 November 1963',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Beatlemania! With the Beatles'},
#  {'BPI Certification': '',
#   'Label': 'Vee-Jay(US)',
#   'RIAA Certification': '',
#   'Released': '10 January 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '2',
#   '\xef\xbb\xbfTitle': 'Introducing... The Beatles'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '5xPlatinum',
#   'Released': '20 January 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'Meet the Beatles!'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '3 February 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Twist and Shout'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '2xPlatinum',
#   'Released': '10 April 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': "The Beatles' Second Album"},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '11 May 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': "The Beatles' Long Tall Sally"},
#  {'BPI Certification': '',
#   'Label': 'United Artists(US)[C]',
#   'RIAA Certification': '4xPlatinum',
#   'Released': '26 June 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': "A Hard Day's Night"},
#  {'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': '',
#   'Released': '10 July 1964',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': ''},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': 'Platinum',
#   'Released': '20 July 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '2',
#   '\xef\xbb\xbfTitle': 'Something New'},
#  {'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Platinum',
#   'Released': '4 December 1964',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Beatles for Sale'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '3xPlatinum',
#   'Released': '15 December 1964',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': "Beatles '65"},
#  {'BPI Certification': '',
#   'Label': 'Parlophone(NZ), Capitol(US)',
#   'RIAA Certification': 'Platinum',
#   'Released': '14 June 1965',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'Beatles VI'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': '',
#   'Released': '6 August 1965',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Help!'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)[C]',
#   'RIAA Certification': '3xPlatinum',
#   'Released': '13 August 1965',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': ''},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': '',
#   'Released': '3 December 1965',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Rubber Soul'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)[C]',
#   'RIAA Certification': '6xPlatinum',
#   'Released': '6 December 1965',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': ''},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '2xPlatinum',
#   'Released': '15 June 1966',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'Yesterday and Today'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': '',
#   'Released': '5 August 1966',
#   'UK Chart Position': '1',
#   'US Chart Position': '\xe2\x80\x94',
#   '\xef\xbb\xbfTitle': 'Revolver'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)[C]',
#   'RIAA Certification': '5xPlatinum',
#   'Released': '8 August 1966',
#   'UK Chart Position': '\xe2\x80\x94',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': ''},
#  {'BPI Certification': '3xPlatinum',
#   'Label': 'Parlophone(UK), Capitol(US)',
#   'RIAA Certification': '11xPlatinum',
#   'Released': '1 June 1967',
#   'UK Chart Position': '1',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': "Sgt. Pepper's Lonely Hearts Club Band"},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK), Capitol(US)',
#   'RIAA Certification': '6xPlatinum',
#   'Released': '27 November 1967',
#   'UK Chart Position': '31[D]',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'Magical Mystery Tour'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Apple(UK), Capitol(US)',
#   'RIAA Certification': '19xPlatinum',
#   'Released': '22 November 1968',
#   'UK Chart Position': '1',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'The Beatles'},
#  {'BPI Certification': 'Silver',
#   'Label': 'Apple(UK), Capitol(US)',
#   'RIAA Certification': 'Platinum',
#   'Released': '13 January 1969',
#   'UK Chart Position': '3',
#   'US Chart Position': '2',
#   '\xef\xbb\xbfTitle': 'Yellow Submarine'},
#  {'BPI Certification': '2xPlatinum',
#   'Label': 'Apple(UK), Capitol(US)',
#   'RIAA Certification': '12xPlatinum',
#   'Released': '26 September 1969',
#   'UK Chart Position': '1',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'Abbey Road'},
#  {'BPI Certification': 'Gold',
#   'Label': 'Apple(UK),United Artists(US)',
#   'RIAA Certification': '4xPlatinum',
#   'Released': '8 May 1970',
#   'UK Chart Position': '1',
#   'US Chart Position': '1',
#   '\xef\xbb\xbfTitle': 'Let It Be'}]
