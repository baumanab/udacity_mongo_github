# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint
import time

OSMFILE = "myseattle.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "North", "East", "South", "West", "Northeast", "Northwest", "Southeast",
            "Southwest", "Circle", "56th", "Loop","Way"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Rd.": "Road",
            "NW": "Northwest",
            "NW.": "Northwest",
            "S": "South",
            "NE": "Northeast",
            "NE.": "Northest",
            "N": "North",
            "S.": "South",
            "N.": "North",
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types


def update_name(name, mapping):

     # YOUR CODE HERE
    """if ';' not in name:
        if 'Suite' in name:
            name = name.split('Suite')[0]
        else:
            sttype = name.split(' ')[-1]
			if mapping.get(sttype) != None:
                name = name.replace(sttype,mapping.get(sttype))
				else:
				name = name
    else:
        name = name.split(';')[-1]
    return name"""
	
	if ';' not in name:
	    if 'Suite' in name:
		name = name.split('Suite')[0]
	    else:
		    name = 'gg'
	else:
	    name = name.split(';')[-1]
    
    
    


def test():
    st_types = audit(OSMFILE)
    #assert len(st_types) == 3
    #pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:            
            better_name = update_name(name, mapping)
            print name, "=>", better_name
           

if __name__ == '__main__':
    test()
# Out:
# North Northgate Way Suite C => North Northgate Way
# Greenwood Ave N. => Greenwood Ave North
# 12th Ave NE => 12th Ave Northeast
# 10th Ave NE => 10th Ave Northeast
# University Way NE => University Way Northeast
# 1st Ave NE => 1st Ave Northeast
# Greenwood Ave N => Greenwood Ave North
# Linden Avenue North;Linden Ave N => Linden Ave N
# E Green Lake Drive N => E Green Lake Drive North
# NW 58th St => NW 58th Street
# NW 60th St => NW 60th Street
# NW 88th St => NW 88th Street
# N 101st St => N 101st Street
# NW 61st St => NW 61st Street
# NW 62nd St => NW 62nd Street
# 14th Ave NW => 14th Ave Northwest
# Ballard Ave NW => Ballard Ave Northwest
# Tallman Ave NW => Tallman Ave Northwest
# 22nd Ave NW => 22nd Ave Northwest
# 25th Ave NW => 25th Ave Northwest
# 3rd Ave NW => 3rd Ave Northwest
# 9th Avenue NW => 9th Avenue Northwest
# 15th Ave NW => 15th Ave Northwest
# 13th Ave NW => 13th Ave Northwest
# 14th Avenue Northwest;14th Ave NW => 14th Ave NW
# ...
